# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Desktop\\weekly task'

# %%
df = pd.read_csv(r"C:\\Users\\dell\\Desktop\\weekly task\spam.csv")
df.head()
# Out:
#    EmailLength  NumLinks  ContainsOffer  Spam
# 0           61         3              1     1
# 1          103         2              1     1
# 2           88         2              1     1
# 3           94         2              1     1
# 4           24         2              1     1
